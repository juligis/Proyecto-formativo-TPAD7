# %% [markdown]
# *Extracion y visualizacion del dataframe se utilizara las librerias necesarias para el proceso*

# %%
# Se cargaran las librerias necesarias para la visualizacion y extraccion de datos en el Dataframe (pandas)
# y  para realizar operaciones en una matriz (Numpy)
import pandas as pd
import numpy as np
# se extrae el Dataframe y la guardamos en una variable (df). Como el dataframe tiene estacios en los encabezados
#crearemos nuestros encabezados para evitar errores de compilacion.
df=pd.read_csv('UncleanedCafe.csv')
df
# Out:
#       Año  Mes            Dia         Presidente  Sacos de cafe producidos  \
# 0       3  ene  jue-02-ene-03  Alvaro Uribe (P1)                    30.800
# 1       3  ene  vie-03-ene-03  Alvaro Uribe (P1)                    30.800
# 2       3  ene  sáb-04-ene-03  Alvaro Uribe (P1)                    30.800
# 3       3  ene  dom-05-ene-03  Alvaro Uribe (P1)                    30.800
# 4       3  ene  lun-06-ene-03  Alvaro Uribe (P1)                    30.800
# ...   ...  ...            ...                ...                       ...
# 7289   22  dic  mar-27-dic-22         Ivan Duque                    31.645
# 7290   22  dic  mié-28-dic-22         Ivan Duque                    31.645
# 7291   22  dic  jue-29-dic-22         Ivan Duque                    31.645
# 7292   22  dic  vie-30-dic-22         Ivan Duque                    31.645
# 7293   22  dic  sáb-31-dic-22         Ivan Duque                    31.645
#
#       Sacos de cafe exportados Valor exportacion (Dolares)  \
# ...

# %% [markdown]
# *se renombran las columnas ya que los encabezados de las columnas ya que estas tienen espacios, lo cual para la filtracion de datos nos dara problemas*

# %%
df.columns = ['año','mes','dia','presidente','sacos_de_cafe_producidos','sacos_de_cafe_exportados','Valor_exportacion_(Dolares)','kilos_cafe_producidos','x9','kilos_cafe_pergamino','carga_cafe','precio_interno_diario','valor_cosecha(pesos)']
df
# Out:
#       año  mes            dia         presidente  sacos_de_cafe_producidos  \
# 0       3  ene  jue-02-ene-03  Alvaro Uribe (P1)                    30.800
# 1       3  ene  vie-03-ene-03  Alvaro Uribe (P1)                    30.800
# 2       3  ene  sáb-04-ene-03  Alvaro Uribe (P1)                    30.800
# 3       3  ene  dom-05-ene-03  Alvaro Uribe (P1)                    30.800
# 4       3  ene  lun-06-ene-03  Alvaro Uribe (P1)                    30.800
# ...   ...  ...            ...                ...                       ...
# 7289   22  dic  mar-27-dic-22         Ivan Duque                    31.645
# 7290   22  dic  mié-28-dic-22         Ivan Duque                    31.645
# 7291   22  dic  jue-29-dic-22         Ivan Duque                    31.645
# 7292   22  dic  vie-30-dic-22         Ivan Duque                    31.645
# 7293   22  dic  sáb-31-dic-22         Ivan Duque                    31.645
#
#       sacos_de_cafe_exportados Valor_exportacion_(Dolares)  \
# ...

# %% [markdown]
# *Visualizacion del tipo de variable de cada columna*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7294 entries, 0 to 7293
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   año                          7294 non-null   int64
#  1   mes                          7294 non-null   object
#  2   dia                          7294 non-null   object
#  3   presidente                   7294 non-null   object
#  4   sacos_de_cafe_producidos     7294 non-null   float64
#  5   sacos_de_cafe_exportados     7294 non-null   float64
#  6   Valor_exportacion_(Dolares)  7294 non-null   object
#  7   kilos_cafe_producidos        7294 non-null   object
#  8   x9                           7294 non-null   object
#  9   kilos_cafe_pergamino         7294 non-null   object
#  10  carga_cafe                   7294 non-null   float64
#  11  precio_interno_diario        7294 non-null   object
#  12  valor_cosecha(pesos)         7294 non-null   object
# ...

# %% [markdown]
# *Revision de los datos , en esta parte se revisara si hay datos nulos. Si se encuentra algun tipo de dato nulo aparecera un TRUE; De lo contrario sino hay aparecera un FALSE*

# %%
print(df.isna())
# Out:
#         año    mes    dia  presidente  sacos_de_cafe_producidos  \
# 0     False  False  False       False                     False
# 1     False  False  False       False                     False
# 2     False  False  False       False                     False
# 3     False  False  False       False                     False
# 4     False  False  False       False                     False
# ...     ...    ...    ...         ...                       ...
# 7289  False  False  False       False                     False
# 7290  False  False  False       False                     False
# 7291  False  False  False       False                     False
# 7292  False  False  False       False                     False
# 7293  False  False  False       False                     False
#
#       sacos_de_cafe_exportados  Valor_exportacion_(Dolares)  \
# 0                        False                        False
# 1                        False                        False
# ...

# %% [markdown]
# *se reemplaza los datos de la columna 'año' para que estos datos se han coherentes y explicitos*

# %%
df['año'] = df['año'].replace(3,2003)
df['año'] = df['año'].replace(4,2004)
df['año'] = df['año'].replace(5,2005)
df['año'] = df['año'].replace(6,2006)
df['año'] = df['año'].replace(7,2007)
df['año'] = df['año'].replace(8,2008)
df['año'] = df['año'].replace(9,2009)
df['año'] = df['año'].replace(10,2010)
df['año'] = df['año'].replace(11,2011)
df['año'] = df['año'].replace(12,2012)
df['año'] = df['año'].replace(13,2013)
df['año'] = df['año'].replace(14,2014)
df['año'] = df['año'].replace(15,2015)
df['año'] = df['año'].replace(16,2016)
df['año'] = df['año'].replace(17,2017)
df['año'] = df['año'].replace(18,2018)
df['año'] = df['año'].replace(19,2019)
df['año'] = df['año'].replace(20,2020)
df['año'] = df['año'].replace(21,2021)
df['año'] = df['año'].replace(22,2022)

df
# Out:
#        año  mes            dia         presidente  sacos_de_cafe_producidos  \
# 0     2003  ene  jue-02-ene-03  Alvaro Uribe (P1)                    30.800
# 1     2003  ene  vie-03-ene-03  Alvaro Uribe (P1)                    30.800
# 2     2003  ene  sáb-04-ene-03  Alvaro Uribe (P1)                    30.800
# 3     2003  ene  dom-05-ene-03  Alvaro Uribe (P1)                    30.800
# 4     2003  ene  lun-06-ene-03  Alvaro Uribe (P1)                    30.800
# ...    ...  ...            ...                ...                       ...
# 7289  2022  dic  mar-27-dic-22         Ivan Duque                    31.645
# 7290  2022  dic  mié-28-dic-22         Ivan Duque                    31.645
# 7291  2022  dic  jue-29-dic-22         Ivan Duque                    31.645
# 7292  2022  dic  vie-30-dic-22         Ivan Duque                    31.645
# 7293  2022  dic  sáb-31-dic-22         Ivan Duque                    31.645
#
# ...

# %% [markdown]
# *ajuste de datos de decimales a miles para este paso se pasa las variables de Enteros(int) a String(str)*, *con el objetivo de eliminar signos de puntuacion y caracteres especificos (%)*

# %%
df['sacos_de_cafe_producidos'] = df['sacos_de_cafe_producidos'].map('{:.3f}'.format)
df['sacos_de_cafe_exportados'] = df['sacos_de_cafe_exportados'].map('{:.3f}'.format)
df['carga_cafe'] = df['carga_cafe'].map('{:.3f}'.format)

df.head()
# Out:
#     año  mes            dia         presidente sacos_de_cafe_producidos  \
# 0  2003  ene  jue-02-ene-03  Alvaro Uribe (P1)                   30.800
# 1  2003  ene  vie-03-ene-03  Alvaro Uribe (P1)                   30.800
# 2  2003  ene  sáb-04-ene-03  Alvaro Uribe (P1)                   30.800
# 3  2003  ene  dom-05-ene-03  Alvaro Uribe (P1)                   30.800
# 4  2003  ene  lun-06-ene-03  Alvaro Uribe (P1)                   30.800
#
#   sacos_de_cafe_exportados Valor_exportacion_(Dolares) kilos_cafe_producidos  \
# 0                   25.167                   2.233.333             1.848.000
# 1                   25.167                   2.233.333             1.848.000
# 2                   25.167                   2.233.333             1.848.000
# 3                   25.167                   2.233.333             1.848.000
# 4                   25.167                   2.233.333             1.848.000
#
#           x9 kilos_cafe_pergamino carga_cafe precio_interno_diario  \
# ...

# %% [markdown]
# *se verifica si las variables quedaron tipo String para hacer el ajuste y eliminacion de signos y puntuacion*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7294 entries, 0 to 7293
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   año                          7294 non-null   int64
#  1   mes                          7294 non-null   object
#  2   dia                          7294 non-null   object
#  3   presidente                   7294 non-null   object
#  4   sacos_de_cafe_producidos     7294 non-null   object
#  5   sacos_de_cafe_exportados     7294 non-null   object
#  6   Valor_exportacion_(Dolares)  7294 non-null   object
#  7   kilos_cafe_producidos        7294 non-null   object
#  8   x9                           7294 non-null   object
#  9   kilos_cafe_pergamino         7294 non-null   object
#  10  carga_cafe                   7294 non-null   object
#  11  precio_interno_diario        7294 non-null   object
#  12  valor_cosecha(pesos)         7294 non-null   object
# ...

# %% [markdown]
# *Ya con nuestras variables transformadas tipo String podemos eliminar puntos y signos para el ajuste de datos*

# %%
df['sacos_de_cafe_producidos'] = df['sacos_de_cafe_producidos'].str.replace(".", "")
df['sacos_de_cafe_exportados'] = df['sacos_de_cafe_exportados'].str.replace(".", "")
df['Valor_exportacion_(Dolares)'] = df['Valor_exportacion_(Dolares)'].str.replace(".", "")
df['kilos_cafe_producidos'] = df['kilos_cafe_producidos'].str.replace(".", "")
df['x9'] = df['x9'].str.replace(",", ".")
df['kilos_cafe_pergamino'] = df['kilos_cafe_pergamino'].str.replace(".", "")
df['carga_cafe'] = df['carga_cafe'].str.replace(".", "")
df['precio_interno_diario'] = df['precio_interno_diario'].str.replace(".", "")
df['valor_cosecha(pesos)'] = df['valor_cosecha(pesos)'].str.replace(".", "")
df['x9'] = df['x9'].str.replace("%", "")
df
# Out:
# <ipython-input-246-60140d44084f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['sacos_de_cafe_producidos'] = df['sacos_de_cafe_producidos'].str.replace(".", "")
# <ipython-input-246-60140d44084f>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['sacos_de_cafe_exportados'] = df['sacos_de_cafe_exportados'].str.replace(".", "")
# <ipython-input-246-60140d44084f>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valor_exportacion_(Dolares)'] = df['Valor_exportacion_(Dolares)'].str.replace(".", "")
# ...

# %% [markdown]
# *Ya con los signos y puntos eliminados podemos pasar de String a Entero para que nuestras variables sean numericas para realizar el machine learning*

# %%
df['sacos_de_cafe_producidos'] = df['sacos_de_cafe_producidos'].astype(int)
df['sacos_de_cafe_exportados'] = df['sacos_de_cafe_exportados'].astype(int)
df['Valor_exportacion_(Dolares)'] = df['Valor_exportacion_(Dolares)'].astype(int)
df['kilos_cafe_producidos'] = df['kilos_cafe_producidos'].astype(int)
df['x9'] = df['x9'].astype(float)
df['kilos_cafe_pergamino'] = df['kilos_cafe_pergamino'].astype(int)
df['carga_cafe'] = df['carga_cafe'].astype(int)
df['precio_interno_diario'] = df['precio_interno_diario'].astype(int)
df['valor_cosecha(pesos)'] = df['valor_cosecha(pesos)'].astype(int)
df
# Out:
#        año  mes            dia         presidente  sacos_de_cafe_producidos  \
# 0     2003  ene  jue-02-ene-03  Alvaro Uribe (P1)                     30800
# 1     2003  ene  vie-03-ene-03  Alvaro Uribe (P1)                     30800
# 2     2003  ene  sáb-04-ene-03  Alvaro Uribe (P1)                     30800
# 3     2003  ene  dom-05-ene-03  Alvaro Uribe (P1)                     30800
# 4     2003  ene  lun-06-ene-03  Alvaro Uribe (P1)                     30800
# ...    ...  ...            ...                ...                       ...
# 7289  2022  dic  mar-27-dic-22         Ivan Duque                     31645
# 7290  2022  dic  mié-28-dic-22         Ivan Duque                     31645
# 7291  2022  dic  jue-29-dic-22         Ivan Duque                     31645
# 7292  2022  dic  vie-30-dic-22         Ivan Duque                     31645
# 7293  2022  dic  sáb-31-dic-22         Ivan Duque                     31645
#
# ...

# %% [markdown]
# *para los porcentajes dividiremos el dato sobre 100 con el fin de indicar que el dato de la columna 'Factor de Rendimiento' que esta ubicada en la x9 sea de manera porcentual*

# %%
df['factor_de_rendimiento'] = (df['x9'] / 100)

# %% [markdown]
# *ya realizada la operacion en la columna X9, el resultado se almacenara en la nueva columna 'FACTOR DE RENDIMIENTO'. Ya que se realizo la operacion se eliminara la columna X9*

# %%
df=df.drop(columns=['x9'])
df
# Out:
#        año  mes            dia         presidente  sacos_de_cafe_producidos  \
# 0     2003  ene  jue-02-ene-03  Alvaro Uribe (P1)                     30800
# 1     2003  ene  vie-03-ene-03  Alvaro Uribe (P1)                     30800
# 2     2003  ene  sáb-04-ene-03  Alvaro Uribe (P1)                     30800
# 3     2003  ene  dom-05-ene-03  Alvaro Uribe (P1)                     30800
# 4     2003  ene  lun-06-ene-03  Alvaro Uribe (P1)                     30800
# ...    ...  ...            ...                ...                       ...
# 7289  2022  dic  mar-27-dic-22         Ivan Duque                     31645
# 7290  2022  dic  mié-28-dic-22         Ivan Duque                     31645
# 7291  2022  dic  jue-29-dic-22         Ivan Duque                     31645
# 7292  2022  dic  vie-30-dic-22         Ivan Duque                     31645
# 7293  2022  dic  sáb-31-dic-22         Ivan Duque                     31645
#
# ...

# %%
df.describe()
# Out:
#                año  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# count  7294.000000               7294.000000               7294.000000
# mean   2012.490403              32064.296408              29796.965725
# std       5.762530               8452.870273               7203.990249
# min    2003.000000              11500.000000              11129.000000
# 25%    2007.000000              26000.000000              25355.000000
# 50%    2012.000000              32333.000000              30258.000000
# 75%    2017.000000              37387.000000              35226.000000
# max    2022.000000              56226.000000              46774.000000
#
#        Valor_exportacion_(Dolares)  kilos_cafe_producidos  \
# count                 7.294000e+03           7.294000e+03
# mean                  6.267343e+06           1.923858e+06
# std                   2.071209e+06           5.071717e+05
# min                   1.600000e+06           6.900000e+05
# ...

# %% [markdown]
# *importamos la libreria seaborn esto con el fin de mostrar datos estadisticos con respecto a la etapa presidencial. El objetivo es visualizar que relacion tiene cada variable con la otra si esta tiene una correlacion=1 tendremos posibilidades de obtenes una buena prediccion, si no hay correlacion hay mayor probabilidad de que no tenga una buena prediccion*

# %%
import seaborn as sns
sns.pairplot(df, hue="presidente")
plt.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# Se realiza el cambio de variable de presidente de P1, P2... a 1, 2, 3...

# %%
df['presidente'] = df['presidente'].str.replace("(P1)",'1')
df['presidente'] = df['presidente'].str.replace("(P2)",'2')
df['presidente'] = df['presidente'].str.replace(")",'')
df['presidente'] = df['presidente'].str.replace("(",'')
df['presidente'] = df['presidente'].str.replace("Alvaro Uribe 1",'1')
df['presidente'] = df['presidente'].str.replace("Alvaro Uribe 2",'2')
df['presidente'] = df['presidente'].str.replace("Juan Manuel Santos 1",'3')
df['presidente'] = df['presidente'].str.replace("Juan Manuel Santos 2",'4')
df['presidente'] = df['presidente'].str.replace("Ivan Duque", '5')

df
# Out:
# <ipython-input-253-e5d35c229bf1>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['presidente'] = df['presidente'].str.replace("(P1)",'1')
# <ipython-input-253-e5d35c229bf1>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['presidente'] = df['presidente'].str.replace("(P2)",'2')
# <ipython-input-253-e5d35c229bf1>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['presidente'] = df['presidente'].str.replace(")",'')
# <ipython-input-253-e5d35c229bf1>:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['presidente'] = df['presidente'].str.replace("(",'')
# ...

# %%
df['presidente']=df['presidente'].astype(int)
# Out:
#        año  mes            dia  presidente  sacos_de_cafe_producidos  \
# 1     2003  ene  vie-03-ene-03           1                     30800
# 2     2003  ene  sáb-04-ene-03           1                     30800
# 3     2003  ene  dom-05-ene-03           1                     30800
# 4     2003  ene  lun-06-ene-03           1                     30800
# 5     2003  ene  mar-07-ene-03           1                     30800
# ...    ...  ...            ...         ...                       ...
# 7289  2022  dic  mar-27-dic-22           5                     31645
# 7290  2022  dic  mié-28-dic-22           5                     31645
# 7291  2022  dic  jue-29-dic-22           5                     31645
# 7292  2022  dic  vie-30-dic-22           5                     31645
# 7293  2022  dic  sáb-31-dic-22           5                     31645
#
#       sacos_de_cafe_exportados  Valor_exportacion_(Dolares)  \
# 1                        25167                      2233333
# ...

# %% [markdown]
# verificamos que todos los datos que necesitamos hayan quedado de tipo entero

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7294 entries, 0 to 7293
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   año                          7294 non-null   int64
#  1   mes                          7294 non-null   object
#  2   dia                          7294 non-null   object
#  3   presidente                   7294 non-null   int64
#  4   sacos_de_cafe_producidos     7294 non-null   int64
#  5   sacos_de_cafe_exportados     7294 non-null   int64
#  6   Valor_exportacion_(Dolares)  7294 non-null   int64
#  7   kilos_cafe_producidos        7294 non-null   int64
#  8   kilos_cafe_pergamino         7294 non-null   int64
#  9   carga_cafe                   7294 non-null   int64
#  10  precio_interno_diario        7294 non-null   int64
#  11  valor_cosecha(pesos)         7294 non-null   int64
#  12  factor_de_rendimiento        7294 non-null   float64
# ...

# %%
#Eliminamos las columnas que no usaremos
df=df.drop(columns=['dia'])
df=df.drop(columns=['mes'])
df.head()
# Out:
#     año  presidente  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# 0  2003           1                     30800                     25167
# 1  2003           1                     30800                     25167
# 2  2003           1                     30800                     25167
# 3  2003           1                     30800                     25167
# 4  2003           1                     30800                     25167
#
#    Valor_exportacion_(Dolares)  kilos_cafe_producidos  kilos_cafe_pergamino  \
# 0                      2233333                1848000               2429581
# 1                      2233333                1848000               2429581
# 2                      2233333                1848000               2429581
# 3                      2233333                1848000               2429581
# 4                      2233333                1848000               2429581
#
#    carga_cafe  precio_interno_diario  valor_cosecha(pesos)  \
# ...

# %%
Para realizar el proceso de ML necesitaremos repartir los datos en 90% de entrenamiento y 10 de texteo

# %%
datos_entrenamiento = df.sample(frac=0.9,random_state=0)
datos_test = df.drop(datos_entrenamiento.index)

# %%
datos_entrenamiento
# Out:
#        año  presidente  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# 4722  2015           4                     46903                     38581
# 4448  2015           4                     25806                     25355
# 831   2005           1                     29100                     28633
# 641   2004           1                     34742                     28645
# 2039  2008           2                     23065                     20710
# ...    ...         ...                       ...                       ...
# 5046  2016           4                     45000                     39677
# 6864  2021           5                     32645                     31839
# 3418  2012           3                     22226                     19032
# 6540  2020           5                     56226                     42226
# 1734  2007           2                     36419                     27226
#
#       Valor_exportacion_(Dolares)  kilos_cafe_producidos  \
# ...

# %%
datos_test
# Out:
#        año  presidente  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# 0     2003           1                     30800                     25167
# 21    2003           1                     30800                     25167
# 24    2003           1                     30800                     25167
# 25    2003           1                     30800                     25167
# 63    2003           1                     20774                     23355
# ...    ...         ...                       ...                       ...
# 7250  2022           5                     35333                     28433
# 7252  2022           5                     35333                     28433
# 7261  2022           5                     35333                     28433
# 7268  2022           5                     31645                     33387
# 7272  2022           5                     31645                     33387
#
#       Valor_exportacion_(Dolares)  kilos_cafe_producidos  \
# ...

# %%
etiquetas_entrenamiento = datos_entrenamiento.pop('sacos_de_cafe_producidos')
etiquetas_test = datos_test.pop('sacos_de_cafe_producidos')

# %%
etiquetas_entrenamiento
# Out:
# 4722    46903
# 4448    25806
# 831     29100
# 641     34742
# 2039    23065
#         ...
# 5046    45000
# 6864    32645
# 3418    22226
# 6540    56226
# 1734    36419
# Name: sacos_de_cafe_producidos, Length: 6565, dtype: int64

# %%
etiquetas_test
# Out:
# 0       30800
# 21      30800
# 24      30800
# 25      30800
# 63      20774
#         ...
# 7250    35333
# 7252    35333
# 7261    35333
# 7268    31645
# 7272    31645
# Name: sacos_de_cafe_producidos, Length: 729, dtype: int64

# %%
importamos la librería que se usará para realizar las predicciones

# %%
from sklearn.linear_model import LinearRegression
modelo = LinearRegression()
modelo.fit(datos_entrenamiento,etiquetas_entrenamiento)
# Out:
# LinearRegression()

# %%
Usamos la regresion lineal y adjuntamos los datos de texteo para realizar las predicciones

# %%
predicciones = modelo.predict(datos_test)
predicciones
# Out:
# array([30800.01545769, 30800.00754591, 30800.00776129, 30800.00888129,
#        20774.2237857 , 35933.32121381, 35933.32121381, 35933.32180276,
#        35933.32180276, 35933.32072582, 31354.83184564, 31354.83420039,
#        31354.83387862, 35900.00351485, 35900.00361572, 35900.00267429,
#        35900.00390151, 35900.00543133, 35900.00517916, 34580.62819143,
#        34580.62460018, 34580.62460018, 34580.62862821, 34580.62976058,
#        34580.62828849, 21322.60078483, 21322.60267659, 26499.99879276,
#        36677.42919563, 36677.43154997, 36677.43235767, 36677.42983147,
#        39200.03305635, 39200.03040705, 40129.06286988, 40129.06550813,
#        37774.15276749, 26551.71427156, 26551.71321406, 26551.71219622,
#        26161.24983935, 26161.24974822, 26161.24892811, 26161.25002159,
#        24599.96008256, 24599.96163372, 35193.4797054 , 35193.47951106,
#        35193.47663122, 31799.9358278 , 31799.94305577, 31799.94490256,
# ...

# %% [markdown]
# importamos una libreria que nos ayude a Imprimir el error porcentual

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
error = np.sqrt(mean_squared_error(etiquetas_test, predicciones))
print("Error porcentual : %f" % (error*100))
# Out:
# Error porcentual : 26.473973

# %%
error = np.sqrt(mean_squared_error(etiquetas_test, predicciones))
error
# Out:
# 0.26473973202051343

# %% [markdown]
# Aquí realizamos la prediccion intruduciendo informacion a las diferentes variables.

# %%
predic= pd.DataFrame(np.array([[23,4.0,38581.0,7354839.0,2814194.0,3603771.0,28830.0,825000.0,2.378489e+10,0.780902]]),columns=['año','presidente','sacos_de_cafe_exportados','Valor_exportacion_(Dolares)','kilos_cafe_producidos','kilos_cafe_pergamino','carga_cafe','precio_interno_diario','valor_cosecha(pesos)','factor_de_rendimiento'])
predic
# Out:
#     año  presidente  sacos_de_cafe_exportados  Valor_exportacion_(Dolares)  \
# 0  23.0         4.0                   38581.0                    7354839.0
#
#    kilos_cafe_producidos  kilos_cafe_pergamino  carga_cafe  \
# 0              2814194.0             3603771.0     28830.0
#
#    precio_interno_diario  valor_cosecha(pesos)  factor_de_rendimiento
# 0               825000.0          2.378489e+10               0.780902

# %%
modelo.predict(predic)
# Out:
# array([46927.53352226])

# %% [markdown]
# ***haremos una prediccion con regresion logistica para predecir el precio interno diario***

# %%
ivan_duque=df.loc[df['presidente']==5]
ivan_duque
# Out:
#        año  presidente  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# 5840  2019           5                     41806                     37613
# 5841  2019           5                     41806                     37613
# 5842  2019           5                     41806                     37613
# 5843  2019           5                     41806                     37613
# 5844  2019           5                     41806                     37613
# ...    ...         ...                       ...                       ...
# 7289  2022           5                     31645                     33387
# 7290  2022           5                     31645                     33387
# 7291  2022           5                     31645                     33387
# 7292  2022           5                     31645                     33387
# 7293  2022           5                     31645                     33387
#
#       Valor_exportacion_(Dolares)  kilos_cafe_producidos  \
# ...

# %%
ivan_duque.to_csv('ivan.csv')

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import mean_absolute_error, r2_score

# %%
ivan_duque.drop(columns=['presidente'])
# Out:
#        año  sacos_de_cafe_producidos  sacos_de_cafe_exportados  \
# 5840  2019                     41806                     37613
# 5841  2019                     41806                     37613
# 5842  2019                     41806                     37613
# 5843  2019                     41806                     37613
# 5844  2019                     41806                     37613
# ...    ...                       ...                       ...
# 7289  2022                     31645                     33387
# 7290  2022                     31645                     33387
# 7291  2022                     31645                     33387
# 7292  2022                     31645                     33387
# 7293  2022                     31645                     33387
#
#       Valor_exportacion_(Dolares)  kilos_cafe_producidos  \
# 5840                      7322581                2508387
# 5841                      7322581                2508387
# ...

# %%
X = ivan_duque[['año','sacos_de_cafe_producidos','sacos_de_cafe_exportados','Valor_exportacion_(Dolares)','kilos_cafe_producidos','kilos_cafe_pergamino','carga_cafe','valor_cosecha(pesos)','factor_de_rendimiento']]
y = ivan_duque['precio_interno_diario']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25, random_state=99)
modelo1 = LogisticRegression()
modelo1.fit(X_train,y_train)
y_predict=modelo1.predict(X_test)
y_predict_train=modelo1.predict(X_train)
mae_test = mean_absolute_error(y_test, y_predict)
r2_test = r2_score(y_test, y_predict)
mae_train = mean_absolute_error(y_train, y_predict_train)
r2_train = r2_score(y_train,y_predict_train)
print(mae_test,r2_test)
print(mae_train,r2_train)
# Out:
# 124325.54945054946 0.9106414636388916
# 122493.11926605504 0.9096913606829324
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
modelo1.predict([[22022,28143,37613,7322581,2508387,3247579,25981,5647626247,0.760625]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([692000])
